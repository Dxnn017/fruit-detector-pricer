# %% [markdown]
# # Normalización y redimensionamiento de imágenes de recorte
# Este notebook procesa todas las imágenes `recorte.png` dentro de la carpeta `recortes`, redimensionándolas a 128x128 píxeles y normalizando sus valores de píxeles a escala [0, 1]. Las imágenes procesadas se guardarán en una nueva carpeta `normalizadas` dentro de `normalizacion`.

# %%
# Importar librerías necesarias
import os
import cv2
import numpy as np
from glob import glob

# %%
# Definir rutas
RECORTES_DIR = '../recortes'
NORMALIZADAS_DIR = './normalizadas'

# Crear estructura de carpetas para normalizadas
def crear_estructura_normalizadas():
    for split in ['train', 'test']:
        split_path = os.path.join(NORMALIZADAS_DIR, split)
        os.makedirs(split_path, exist_ok=True)
        origen_split = os.path.join(RECORTES_DIR, split)
        if not os.path.exists(origen_split):
            print(f"Carpeta no encontrada: {origen_split}")
            continue
        clases = os.listdir(origen_split)
        for clase in clases:
            os.makedirs(os.path.join(split_path, clase), exist_ok=True)
crear_estructura_normalizadas()

# %%
# Normalizar y redimensionar imágenes de recorte.png
for split in ['train', 'test']:
    for clase in os.listdir(os.path.join(RECORTES_DIR, split)):
        in_dir = os.path.join(RECORTES_DIR, split, clase)
        out_dir = os.path.join(NORMALIZADAS_DIR, split, clase)
        recortes = glob(os.path.join(in_dir, '*_recorte.png'))
        for recorte_path in recortes:
            img = cv2.imread(recorte_path)
            if img is None:
                print(f"No se pudo leer {recorte_path}")
                continue
            # Redimensionar a 128x128
            img_resized = cv2.resize(img, (128, 128), interpolation=cv2.INTER_AREA)
            # Normalizar a [0, 1]
            img_normalized = img_resized.astype(np.float32) / 255.0
            # Guardar como PNG (reescala a [0, 255] para guardar)
            out_path = os.path.join(out_dir, os.path.basename(recorte_path))
            cv2.imwrite(out_path, (img_normalized * 255).astype(np.uint8))
            print(f"Normalizada y guardada: {out_path}")
# Out:
# Normalizada y guardada: ./normalizadas/train/Peach 2/182_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/137_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/177_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/8_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/294_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/200_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_146_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_150_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/293_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_245_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_177_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_81_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_254_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_55_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_101_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_253_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/127_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_50_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/85_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_260_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_210_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/304_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/35_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_93_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_180_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_288_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_128_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_112_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/81_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_108_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/44_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/87_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/205_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/192_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_285_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_7_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/45_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/305_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/172_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/39_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/198_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_4_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_98_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/248_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_228_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/234_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/181_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_250_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_288_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_164_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/11_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_139_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/64_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_149_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/17_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_151_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_268_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_249_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_94_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/313_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/327_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_281_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/72_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_275_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_144_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_147_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_278_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/62_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/280_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_255_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_126_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_277_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/209_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/251_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_304_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/217_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_140_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_184_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/320_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_283_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/278_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/13_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/152_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_274_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_62_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/0_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/175_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_72_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/60_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_87_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/82_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_24_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_85_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_134_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_104_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_147_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/38_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_215_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/69_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/132_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/130_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_138_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_0_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/56_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/231_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_110_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/63_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_135_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_89_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_262_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/174_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_54_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_92_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/77_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/145_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_239_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/302_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_80_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_90_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/323_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_36_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/253_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_116_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_150_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_133_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_220_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_109_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_35_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r_107_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_39_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_125_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2/r2_297_100_recorte.png
# Normalizada y guardada: ./normalizadas/train/Peach 2